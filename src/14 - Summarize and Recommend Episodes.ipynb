# %%
import pathlib
import json
from helpers import ai
from pprint import pprint

# %%
NBS_DIR = pathlib.Path().resolve().parent
BASE_DIR = NBS_DIR
DATASET_DIR = BASE_DIR / "dataset"

# %%
for path in list(DATASET_DIR.glob("**/**/detail.json")):
    post_detail_dir = path.parent
    post_detail = json.loads(path.read_text())
    podcasts_dir = post_detail_dir / "podcasts"
    recommended_podcasts_dir = post_detail_dir / "recommended"
    for transcript_path in podcasts_dir.glob("**/**/transcript.txt"):
        podcast_detail_dir = transcript_path.parent
        podcast_detail_path = podcast_detail_dir / 'podcast.json'
        if not podcast_detail_path.exists():
            continue
        podcast_detail = json.loads(podcast_detail_path.read_text())
        podcast_title = podcast_detail.get('trackName')
        podcast_id = podcast_detail.get('trackId')
        podcast_description = podcast_detail.get('description')
        apple_podcast_track_url = podcast_detail.get('trackViewUrl')
        episode_url = podcast_detail.get('episodeUrl')
        content = transcript_path.read_text()
        try:
            result_data, is_json = ai.extract_summary_and_keywords(content=content)
        except:
            result_data = {'summary': None, 'keywords': []}
        recommendation = {
            'title': podcast_title,
            'description': podcast_description,
            'links': {
                'applePodcasts': apple_podcast_track_url,
                'direct': episode_url,
            },
            'ai_summary': result_data.get('summary'),
            'ai_keywords': result_data.get('keywords'),
        }
        print(recommendation)
        recommended_podcasts_dir.mkdir(exist_ok=True)
        outpath = recommended_podcasts_dir / f"{podcast_id}.json"
        outpath.write_text(json.dumps(recommendation))
# Out:
# {'title': '.Net Open Source e Systemd again', 'description': 'Olá pessoal! Voltamos com mais um episódio do Opencast, milagrosamente mantendo a periodicidade semanal. Este episódio marca a volta do querido participante Aprígio Simões que voltou falando italiano.\n\nNão tem como evitar, neste episódio voltamos a falar sobre o Systemd, tanto sobre a descontinuação do kfreebsd, como o funcionamento e vantagens/desvantagens do novo sistema.\n\nSe você é do Rio Grande do Sul ou Santa Catarina e precisa de serviços de cabeamento estruturado, câmeras de segurança dentro do padrão de cabeamento estruturado, nobreaks(venda e manutenção), som ambiente, equipamentos de informática de padrão corporativo ou ainda consultoria na área de T.I., não deixe de entrar em contato com nosso patrocinador Dataware pelo telefone (54) 3712 0177.\n\nLinks do episódio\n\n Debian com Kernel BSD MÓÓÓÓREU\n Microsoft adere ao comunismo\n Blog do .Net\n Github da Microsoft\n  Ajude a Fundação Gnome a defender a marca Gnome\n  Gnome Venceu\n  GCC vs CLANG\n  Robô Philae no cometa 67P\n  Pinguins são estuprados por focas (aí surgiu o Guia Foca Linux)\n\nTwitter: @tecnologiaabert\n\nFacebook:\xa0http://www.facebook.com/tecnologiaaberta\n\nGoogle+:\xa0Tecnologia Aberta\n\nYoutube:\xa0Tecnologia Aberta\n\nE-Mail: opencast@tecnologiaaberta.com.br\n\nFeed do Opencast: http://tecnologiaaberta.com.br/feed/opencast/\n\niTunes: http://itunes.apple.com/br/podcast/id424732898\n\nCréditos das músicas usadas neste programa:\nJosh Woodward\n\n\n--- \n\nSend in a voice message: https://podcasters.spotify.com/pod/show/opencast/message', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/net-open-source-e-systemd-again/id1458279976?i=1000433799692&uo=4', 'direct': 'https://anchor.fm/s/9789fe8/podcast/play/2639837/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fproduction%2F2019-2-14%2F11310812-44100-2-f90116f92ac91.mp3'}, 'ai_summary': 'Eu acredito que a Microsoft está aprendendo com a comunidade Linux e o open source. É interessante ver como eles estão aprendendo e evoluindo com as novas tecnologias. Embora não seja uma coisa treinável, eles estão aprendendo muito.', 'ai_keywords': [{'value': 'Microsoft', 'rank': 1}, {'value': 'Linux', 'rank': 2}, {'value': 'open source', 'rank': 3}, {'value': 'communidade', 'rank': 4}, {'value': 'aprendizado', 'rank': 5}]}
# {'title': 'systemd su WSL e PNG che contengono il loro stesso MD5', 'description': "/** Links */\n\nMicrosoft & Canonical Bring systemd To WSL - https://www.phoronix.com/news/Microsoft-WSL-systemd\n\nMicrosoft adds 'systemd' to the Windows Subsystem for Linux - https://www.bleepingcomputer.com/news/microsoft/microsoft-adds-systemd-to-the-windows-subsystem-for-linux/\n\nThis image shows its own MD5 checksum — and it's kind of a big deal - https://www.bleepingcomputer.com/news/security/this-image-shows-its-own-md5-checksum-and-its-kind-of-a-big-deal/\n\n#wsl #systemd #microsoft #canonical #linux #png #md5 #hashquine\n\n\n--- \n\nSend in a voice message: https://podcasters.spotify.com/pod/show/edodusi/message", 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/systemd-su-wsl-e-png-che-contengono-il-loro-stesso-md5/id1641061765?i=1000580771305&uo=4', 'direct': 'https://anchor.fm/s/b1bf48a0/podcast/play/58193690/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fstaging%2F2022-8-27%2F287900717-44100-2-14b62f86d8c1d.mp3'}, 'ai_summary': 'Microsoft and Canonical have worked together to add Linux support to Windows 10. Systemd is a software that acts as a service manager and allows for the initialization, deployment, and management of services in the system. The first process created by the systemd is the init process, which is responsible for starting and managing all other processes. This change has required a rethinking of the architecture to accommodate the addition of Linux services.', 'ai_keywords': [{'value': 'Windows', 'rank': 1}, {'value': 'Linux', 'rank': 2}, {'value': 'systemd', 'rank': 3}, {'value': 'services', 'rank': 4}, {'value': 'init process', 'rank': 5}]}
# {'title': 'Supply Chain Integrity, Format Strings, Systemd Bug, Instagram Bounty, & Refactoring - ASW #155', 'description': 'This week in the AppSec Weekly News John and Mike discuss: SLSA framework for supply chain integrity, Wi-Fi network of doom for iPhones, seven-year old systemd privesc, $30K for an API call, Codecov refactors from Bash, using the AST to refactor Python, shifting left and right, and more!\n \xa0\n Visit https://www.securityweekly.com/asw for all the latest episodes!\n Show Notes: https://securityweekly.com/asw155', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/supply-chain-integrity-format-strings-systemd-bug-instagram/id121896233?i=1000526377303&uo=4', 'direct': 'https://dts.podtrac.com/redirect.mp3/traffic.libsyn.com/secure/securityweeklytv/ASW_155_-_AppSec_News-0_converted_sd.mp4?dest-id=292819'}, 'ai_summary': "In this episode of Security Weekly, John and I discussed the concept of shift left security and its limitations. We talked about how shift left security has become a bit of a misnomer and why it's important to remember that there's still some deployed code monitoring that we need to check on. We also discussed the importance of preaching to the rest of the world and giving developers tools that are designed for their environment and speak language they know. John had some interesting points and I agreed with him that shift left is still quite a thing and it's important to focus on developer first when it comes to security tools. Thank you for listening!", 'ai_keywords': [{'value': 'shift left security', 'rank': 1}, {'value': 'developer first', 'rank': 2}, {'value': 'deployed code monitoring', 'rank': 3}, {'value': 'security tools', 'rank': 4}, {'value': 'preaching to the rest of the world', 'rank': 5}]}
# {'title': '037 - Server Infrastructure, systemd, and the Business Side of Sidekiq with Mike Perham', 'description': 'Me and Mike start with a detailed discussion of how systemd and systemctl work in Linux, then transition into server infrastructure in general, then finally we talk about the business side of Sidekiq.\nSidekiqDerry Girls', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/037-server-infrastructure-systemd-and-the-business/id1464180320?i=1000469341474&uo=4', 'direct': 'https://www.buzzsprout.com/1878319/9478278-037-server-infrastructure-systemd-and-the-business-side-of-sidekiq-with-mike-perham.mp3'}, 'ai_summary': 'Mike speaks about Sidekick, an open-source project he created to help him scale his business. He discusses the importance of providing good documentation for open-source projects and how it has helped him build a loyal community of users. Mike also shares his thoughts on the difference between open-source and commercial success, and how he prioritizes his time and energy based on the level of support he receives from his customers.', 'ai_keywords': [{'value': ' Sidekick', 'rank': 1}, {'value': 'open-source', 'rank': 2}, {'value': 'business', 'rank': 3}, {'value': 'documentation', 'rank': 4}, {'value': 'community', 'rank': 5}]}
# {'title': '228: Fedora Asahi, GNOME Tiling, KDE Plasma 6, systemd, Zorin, Inkscape & more Linux news!', 'description': 'On this episode of This Week in Linux, Asahi Linux announced a major change with a new flagship distro for using Linux on Apple Silicon. GNOME and KDE released some exciting news for their respective desktop environments. systemd has a cool new feature called soft reboot and we have a whole lot of distro news for you from Arch Linux, Zorin OS, MX Linux and more. If this is your first TWIL, This Week in Linux is the news show that keeps you up to date with what’s going on in the Linux and Open Source world. So let’s jump right into Your Source for Linux GNews.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFORUM THREAD ►► https://forum.tuxdigital.com/t/228-fedora-asahi-gnome-tiling-kde-plasma-6-systemd-zorin-inkscape-amp-more-linux-news/5914\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSPONSORED BY:LINBIT ►► https://linbit.com/\n\n\n\n\n\n\n\nTWITTER ►► https://twitter.com/michaeltunnellMASTODON ►► https://mastodon.social/@MichaelTunnell\n\n\n\n\n\n\n\nMERCH ►► https://tuxdigital.com/storeBECOME A PATRON ►► https://tuxdigital.com/membership\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nChapters:\n\n\n\n\n\n\n\n00:00 TWIL 228 Intro00:44 Fedora Asahi Remix: New Flagship Distro for Apple Silicon – [ link ]02:21 GNOME Considers New Tiling Window Management – [ link ]05:59 LINBIT ( https://linbit.com )07:23 KDE Plasma 6 News – [ link ]13:04 systemd 254 Released – [ link ]14:17 Inkscape 1.3 Released – [ link ]15:22 Arch Linux New Release – [ link ]17:02 Zorin OS 16.3 Released – [ link ]19:19 MX Linux 23 Released – [ link ]21:07 Whonix 17 Released – [ link ]22:37 Outro\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOther Videos:17 KDE Plasma Features That You Didn’t Know About: https://www.youtube.com/watch?v=zhPIwFC4qFsGamify Your Life with Habitica, A To-Do List RPG To Get Things Done: https://www.youtube.com/watch?v=230NecNTaSA5 Reasons Why I Use KDE Plasma: https://youtu.be/b0KA6IsO1M87 Reasons Why Firefox Is My Favorite Web Browser: https://youtu.be/bGTBH9yr8uwHow To Use Firefox’s Best Feature, Multi-Account Containers: https://youtu.be/FfN5L5zAJUo', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/228-fedora-asahi-gnome-tiling-kde-plasma-6-systemd/id1689396651?i=1000623600545&uo=4', 'direct': 'https://media.blubrry.com/tuxdigital_thisweekinlinux_mp3/aphid.fireside.fm/d/1437767933/2389be04-5c79-485e-b1ca-3a5b2cebb006/ad5270a5-e830-41c6-bc57-219a04b528af.mp3'}, 'ai_summary': 'This week in Linux saw the release of several new versions of popular Linux distributions, including Arch Linux, Zorin OS, and MX Linux. These releases often come with updated software packages, bug fixes, and other improvements. Additionally, Honix, a privacy-focused Linux distribution, released a new version based on Debian 12 and Bookworm. Honnex provides a layer of protection for internet traffic through its innovative architecture, making it difficult for malware and IP leaks to occur.', 'ai_keywords': [{'value': 'Arch Linux', 'rank': 1}, {'value': 'Zorin OS', 'rank': 2}, {'value': 'MX Linux', 'rank': 3}, {'value': 'Honix', 'rank': 4}]}
# {'title': 'Linux Mint, Mir, Peppermint, MX Linux, VirtualBox, Hacking Books, systemd | This Week in Linux 48', 'description': '[tdpodcast mode=”ytembed” podcast=”thisweekinlinux” episode=”48″]\n\nOn this episode of This Week in Linux, we have a LOT of Distro News from Linux Mint, Peppermint, MX Linux, GParted, Lubuntu and Bedrock Linux. If you haven’t heard of Bedrock, you will certainly want to stick around for that. Then we’ll check out some App News from VirtualBox, Handbrake and some command-line goodies, Grep & Sed. Later in the show, we’ll cover some Core News with Coreboot and everyone’s favorite, systemd. There’s also some Linux Gaming sales we’ll check out as well as a Hacking Books Bundle from Humble Bundle. All that and much more!\n\n\n\n[tdpodcast mode=”downloads” podcast=”thisweekinlinux” episode=”48″]\n\n[tdpodcast mode=”patrononly” podcast=”thisweekinlinux” episode=”48″ patronextras=”0″ patronshowstream=”1″ patronaftershow=”1″]\n\n[tdpodcast mode=”subscribe” podcast=”thisweekinlinux”]\n\nSegment Index\n\n\n\n* 00:46 = 20% OFF “Linux is Everywhere” Shirts, Hoodies, etc · [link]\n\n* 01:26 = VirtualBox 6.0 Released · [link]\n\n* 04:31 = HandBrake 1.2 Released · [link]\n\n* 07:05 = Grep 3.3 & Sed 4.6 Released · [Links: Grep, Sed]\n\n* 10:37 = Mir 1.1 Released · [link]\n\n* 13:18 = Hacking for the Holidays – Humble Bundle · [link]\n\n* 15:17 = Linux Mint 19.1 Released · [link]\n\n* 17:41 = GParted Live 0.33.0-1 Released · [link]\n\n* 20:41 = Lubuntu To Deprecate 32-Bit Releases · [link]\n\n* 24:35 = Peppermint 9 Respin Released · [link]\n\n* a href="https://www.', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/linux-mint-mir-peppermint-mx-linux-virtualbox-hacking/id1689396651?i=1000614308081&uo=4', 'direct': 'https://media.blubrry.com/tuxdigital_thisweekinlinux_mp3/aphid.fireside.fm/d/1437767933/2389be04-5c79-485e-b1ca-3a5b2cebb006/50f62a41-f26f-4ea1-ba63-1089ec758f4a.mp3'}, 'ai_summary': "In this week's episode of This Week in Linux, Michael talks about the latest news and developments in the world of Linux. Topics include Microsoft's announcement of Project Mew, an open source UEFI implementation, which could potentially allow for running Linux on Surface hardware, and a new blog post from Microsoft explaining their reasoning behind making their own UEFI implementation.", 'ai_keywords': [{'value': 'UEFI', 'rank': 1}, {'value': 'Microsoft', 'rank': 2}, {'value': 'Project Mew', 'rank': 3}, {'value': 'Surface hardware', 'rank': 4}, {'value': 'Linux', 'rank': 5}]}
# {'title': 'Magematix & Datalog // Live @ STÜX', 'description': 'Magematix & Datalog // Live @ STÜX\n2022_july\n\n✪ // www.tilos.hu \n✪ // FM90.3\n✪ // www.facebook.com/beatsafaridnb/\n✪ // iTunes Podcast // https://podcasts.apple.com/hu/podcast/tilos-radio-show/id1535637045', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/magematix-datalog-live-st%C3%BCx/id1535637045?i=1000575413261&uo=4', 'direct': 'https://feeds.soundcloud.com/stream/1305959695-beatsafaridnb-magematix-datalog-live-stux.mp3'}, 'ai_summary': 'This ice has different thicknesses, ranging from 1.5mm to 3.5mm.', 'ai_keywords': [{'value': 'a', 'rank': 1}, {'value': 'b', 'rank': 2}, {'value': 'c', 'rank': 3}, {'value': 'd', 'rank': 4}, {'value': 'e', 'rank': 5}]}
# {'title': 'Episode 58: All about some Datalog', 'description': "This week kicks off with a recap of GigCity Elixir. Chris and Amos encourage people to attend smaller conferences because, seriously, they're way more fun.\n\n\nChris is building RPC to see if it helps solve some of the coordination issues that he's experiencing at work. The conversation moves to the concept of autonomy and leverage in software systems and how to help teams align on larger goals.\n\n\nDave's latest talk from GigCity is referenced and Chris expounds on his love for Datalog.\n\n\nFinally the hosts indulge in multiple divergences in which they divulge information about their personal lives.\nSupport Elixir Outlaws", 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/episode-58-all-about-some-datalog/id1372617417?i=1000456176903&uo=4', 'direct': 'https://aphid.fireside.fm/d/1437767933/4b3f9fe7-b118-4f29-b6ee-7baf2571b03c/b7a58ef1-dca0-4bba-ae85-f03380b89403.mp3'}, 'ai_summary': "Discussing Halloween costumes and divulging information about children's Halloween plans. Chris shares his struggles with remembering his youngest son's name, while the hosts discuss their own Halloween costume ideas. They also talk about a movie called 'Betty's Spaghetti' and its impact on them as children.", 'ai_keywords': [{'value': 'Halloween', 'rank': 1}, {'value': 'costumes', 'rank': 2}, {'value': 'children', 'rank': 3}, {'value': "Betty's Spaghetti", 'rank': 4}, {'value': 'movie', 'rank': 5}]}
# {'title': 'Jika Aku Menjadi Data Scientist', 'description': 'Sebagian dari kamu mungkin terinspirasi ingin bekarir sebagai data scientist. Tapi apakah kamu benar sudah tau lingkup kerja seorang DS atau data scientist? Jurusan kuliah apa yang sebaiknya ditempuh? Kalau sudah terlanjur ambil jurusan modern art gak bisa jadi data scientist dong? Eits! pertanyaan-pertanyan tersebut (mungkin) akan dijawab di episode DataLog kali ini! Mari merapat dan simak!', 'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/jika-aku-menjadi-data-scientist/id1569195021?i=1000536467166&uo=4', 'direct': 'https://anchor.fm/s/5c1a3db0/podcast/play/40595102/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fstaging%2F2021-8-21%2F56e58419-49c9-f7c4-3f70-d94bae152165.mp3'}, 'ai_summary': "In this podcast, we will be discussing the importance of data science in today's world. We will be talking about how data science is revolutionizing various industries and how it can help businesses make informed decisions. We will also be discussing the skills required to become a data scientist and the job prospects available in this field. ", 'ai_keywords': [{'value': 'data science', 'rank': 1}, {'value': 'industry', 'rank': 2}, {'value': 'business', 'rank': 3}, {'value': 'informed decision', 'rank': 4}, {'value': 'skill', 'rank': 5}]}

# %%
for path in list(DATASET_DIR.glob("**/recommended/**")):
    print(path)
    for rec_path in path.glob("*.json"):
        pprint(json.loads(rec_path.read_text()))
# Out:
# /Users/cfe/Dev/smarter-scraping/dataset/2024-02-13/posts/39343831/recommended
# {'ai_keywords': [{'rank': 1, 'value': ' Sidekick'},
#                  {'rank': 2, 'value': 'open-source'},
#                  {'rank': 3, 'value': 'business'},
#                  {'rank': 4, 'value': 'documentation'},
#                  {'rank': 5, 'value': 'community'}],
#  'ai_summary': 'Mike speaks about Sidekick, an open-source project he created '
#                'to help him scale his business. He discusses the importance of '
#                'providing good documentation for open-source projects and how '
#                'it has helped him build a loyal community of users. Mike also '
#                'shares his thoughts on the difference between open-source and '
#                'commercial success, and how he prioritizes his time and energy '
#                'based on the level of support he receives from his customers.',
#  'description': 'Me and Mike start with a detailed discussion of how systemd '
#                 'and systemctl work in Linux, then transition into server '
#                 'infrastructure in general, then finally we talk about the '
#                 'business side of Sidekiq.\n'
#                 'SidekiqDerry Girls',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/037-server-infrastructure-systemd-and-the-business/id1464180320?i=1000469341474&uo=4',
#            'direct': 'https://www.buzzsprout.com/1878319/9478278-037-server-infrastructure-systemd-and-the-business-side-of-sidekiq-with-mike-perham.mp3'},
#  'title': '037 - Server Infrastructure, systemd, and the Business Side of '
#           'Sidekiq with Mike Perham'}
# {'ai_keywords': [{'rank': 1, 'value': 'Microsoft'},
#                  {'rank': 2, 'value': 'Linux'},
#                  {'rank': 3, 'value': 'open source'},
#                  {'rank': 4, 'value': 'communidade'},
#                  {'rank': 5, 'value': 'aprendizado'}],
#  'ai_summary': 'Eu acredito que a Microsoft está aprendendo com a comunidade '
#                'Linux e o open source. É interessante ver como eles estão '
#                'aprendendo e evoluindo com as novas tecnologias. Embora não '
#                'seja uma coisa treinável, eles estão aprendendo muito.',
#  'description': 'Olá pessoal! Voltamos com mais um episódio do Opencast, '
#                 'milagrosamente mantendo a periodicidade semanal. Este '
#                 'episódio marca a volta do querido participante Aprígio Simões '
#                 'que voltou falando italiano.\n'
#                 '\n'
#                 'Não tem como evitar, neste episódio voltamos a falar sobre o '
#                 'Systemd, tanto sobre a descontinuação do kfreebsd, como o '
#                 'funcionamento e vantagens/desvantagens do novo sistema.\n'
#                 '\n'
#                 'Se você é do Rio Grande do Sul ou Santa Catarina e precisa de '
#                 'serviços de cabeamento estruturado, câmeras de segurança '
#                 'dentro do padrão de cabeamento estruturado, nobreaks(venda e '
#                 'manutenção), som ambiente, equipamentos de informática de '
#                 'padrão corporativo ou ainda consultoria na área de T.I., não '
#                 'deixe de entrar em contato com nosso patrocinador Dataware '
#                 'pelo telefone (54) 3712 0177.\n'
#                 '\n'
#                 'Links do episódio\n'
#                 '\n'
#                 ' Debian com Kernel BSD MÓÓÓÓREU\n'
#                 ' Microsoft adere ao comunismo\n'
#                 ' Blog do .Net\n'
#                 ' Github da Microsoft\n'
#                 '  Ajude a Fundação Gnome a defender a marca Gnome\n'
#                 '  Gnome Venceu\n'
#                 '  GCC vs CLANG\n'
#                 '  Robô Philae no cometa 67P\n'
#                 '  Pinguins são estuprados por focas (aí surgiu o Guia Foca '
#                 'Linux)\n'
#                 '\n'
#                 'Twitter: @tecnologiaabert\n'
#                 '\n'
#                 'Facebook:\xa0http://www.facebook.com/tecnologiaaberta\n'
#                 '\n'
#                 'Google+:\xa0Tecnologia Aberta\n'
#                 '\n'
#                 'Youtube:\xa0Tecnologia Aberta\n'
#                 '\n'
#                 'E-Mail: opencast@tecnologiaaberta.com.br\n'
#                 '\n'
#                 'Feed do Opencast: '
#                 'http://tecnologiaaberta.com.br/feed/opencast/\n'
#                 '\n'
#                 'iTunes: http://itunes.apple.com/br/podcast/id424732898\n'
#                 '\n'
#                 'Créditos das músicas usadas neste programa:\n'
#                 'Josh Woodward\n'
#                 '\n'
#                 '\n'
#                 '--- \n'
#                 '\n'
#                 'Send in a voice message: '
#                 'https://podcasters.spotify.com/pod/show/opencast/message',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/net-open-source-e-systemd-again/id1458279976?i=1000433799692&uo=4',
#            'direct': 'https://anchor.fm/s/9789fe8/podcast/play/2639837/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fproduction%2F2019-2-14%2F11310812-44100-2-f90116f92ac91.mp3'},
#  'title': '.Net Open Source e Systemd again'}
# {'ai_keywords': [{'rank': 1, 'value': 'shift left security'},
#                  {'rank': 2, 'value': 'developer first'},
#                  {'rank': 3, 'value': 'deployed code monitoring'},
#                  {'rank': 4, 'value': 'security tools'},
#                  {'rank': 5, 'value': 'preaching to the rest of the world'}],
#  'ai_summary': 'In this episode of Security Weekly, John and I discussed the '
#                'concept of shift left security and its limitations. We talked '
#                'about how shift left security has become a bit of a misnomer '
#                "and why it's important to remember that there's still some "
#                'deployed code monitoring that we need to check on. We also '
#                'discussed the importance of preaching to the rest of the world '
#                'and giving developers tools that are designed for their '
#                'environment and speak language they know. John had some '
#                'interesting points and I agreed with him that shift left is '
#                "still quite a thing and it's important to focus on developer "
#                'first when it comes to security tools. Thank you for '
#                'listening!',
#  'description': 'This week in the AppSec Weekly News John and Mike discuss: '
#                 'SLSA framework for supply chain integrity, Wi-Fi network of '
#                 'doom for iPhones, seven-year old systemd privesc, $30K for an '
#                 'API call, Codecov refactors from Bash, using the AST to '
#                 'refactor Python, shifting left and right, and more!\n'
#                 ' \xa0\n'
#                 ' Visit https://www.securityweekly.com/asw for all the latest '
#                 'episodes!\n'
#                 ' Show Notes: https://securityweekly.com/asw155',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/supply-chain-integrity-format-strings-systemd-bug-instagram/id121896233?i=1000526377303&uo=4',
#            'direct': 'https://dts.podtrac.com/redirect.mp3/traffic.libsyn.com/secure/securityweeklytv/ASW_155_-_AppSec_News-0_converted_sd.mp4?dest-id=292819'},
#  'title': 'Supply Chain Integrity, Format Strings, Systemd Bug, Instagram '
#           'Bounty, & Refactoring - ASW #155'}
# {'ai_keywords': [{'rank': 1, 'value': 'UEFI'},
#                  {'rank': 2, 'value': 'Microsoft'},
#                  {'rank': 3, 'value': 'Project Mew'},
#                  {'rank': 4, 'value': 'Surface hardware'},
#                  {'rank': 5, 'value': 'Linux'}],
#  'ai_summary': "In this week's episode of This Week in Linux, Michael talks "
#                'about the latest news and developments in the world of Linux. '
#                "Topics include Microsoft's announcement of Project Mew, an "
#                'open source UEFI implementation, which could potentially allow '
#                'for running Linux on Surface hardware, and a new blog post '
#                'from Microsoft explaining their reasoning behind making their '
#                'own UEFI implementation.',
#  'description': '[tdpodcast mode=”ytembed” podcast=”thisweekinlinux” '
#                 'episode=”48″]\n'
#                 '\n'
#                 'On this episode of This Week in Linux, we have a LOT of '
#                 'Distro News from Linux Mint, Peppermint, MX Linux, GParted, '
#                 'Lubuntu and Bedrock Linux. If you haven’t heard of Bedrock, '
#                 'you will certainly want to stick around for that. Then we’ll '
#                 'check out some App News from VirtualBox, Handbrake and some '
#                 'command-line goodies, Grep & Sed. Later in the show, we’ll '
#                 'cover some Core News with Coreboot and everyone’s favorite, '
#                 'systemd. There’s also some Linux Gaming sales we’ll check out '
#                 'as well as a Hacking Books Bundle from Humble Bundle. All '
#                 'that and much more!\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '[tdpodcast mode=”downloads” podcast=”thisweekinlinux” '
#                 'episode=”48″]\n'
#                 '\n'
#                 '[tdpodcast mode=”patrononly” podcast=”thisweekinlinux” '
#                 'episode=”48″ patronextras=”0″ patronshowstream=”1″ '
#                 'patronaftershow=”1″]\n'
#                 '\n'
#                 '[tdpodcast mode=”subscribe” podcast=”thisweekinlinux”]\n'
#                 '\n'
#                 'Segment Index\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '* 00:46 = 20% OFF “Linux is Everywhere” Shirts, Hoodies, etc '
#                 '· [link]\n'
#                 '\n'
#                 '* 01:26 = VirtualBox 6.0 Released · [link]\n'
#                 '\n'
#                 '* 04:31 = HandBrake 1.2 Released · [link]\n'
#                 '\n'
#                 '* 07:05 = Grep 3.3 & Sed 4.6 Released · [Links: Grep, Sed]\n'
#                 '\n'
#                 '* 10:37 = Mir 1.1 Released · [link]\n'
#                 '\n'
#                 '* 13:18 = Hacking for the Holidays – Humble Bundle · [link]\n'
#                 '\n'
#                 '* 15:17 = Linux Mint 19.1 Released · [link]\n'
#                 '\n'
#                 '* 17:41 = GParted Live 0.33.0-1 Released · [link]\n'
#                 '\n'
#                 '* 20:41 = Lubuntu To Deprecate 32-Bit Releases · [link]\n'
#                 '\n'
#                 '* 24:35 = Peppermint 9 Respin Released · [link]\n'
#                 '\n'
#                 '* a href="https://www.',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/linux-mint-mir-peppermint-mx-linux-virtualbox-hacking/id1689396651?i=1000614308081&uo=4',
#            'direct': 'https://media.blubrry.com/tuxdigital_thisweekinlinux_mp3/aphid.fireside.fm/d/1437767933/2389be04-5c79-485e-b1ca-3a5b2cebb006/50f62a41-f26f-4ea1-ba63-1089ec758f4a.mp3'},
#  'title': 'Linux Mint, Mir, Peppermint, MX Linux, VirtualBox, Hacking Books, '
#           'systemd | This Week in Linux 48'}
# {'ai_keywords': [{'rank': 1, 'value': 'Windows'},
#                  {'rank': 2, 'value': 'Linux'},
#                  {'rank': 3, 'value': 'systemd'},
#                  {'rank': 4, 'value': 'services'},
#                  {'rank': 5, 'value': 'init process'}],
#  'ai_summary': 'Microsoft and Canonical have worked together to add Linux '
#                'support to Windows 10. Systemd is a software that acts as a '
#                'service manager and allows for the initialization, deployment, '
#                'and management of services in the system. The first process '
#                'created by the systemd is the init process, which is '
#                'responsible for starting and managing all other processes. '
#                'This change has required a rethinking of the architecture to '
#                'accommodate the addition of Linux services.',
#  'description': '/** Links */\n'
#                 '\n'
#                 'Microsoft & Canonical Bring systemd To WSL - '
#                 'https://www.phoronix.com/news/Microsoft-WSL-systemd\n'
#                 '\n'
#                 "Microsoft adds 'systemd' to the Windows Subsystem for Linux - "
#                 'https://www.bleepingcomputer.com/news/microsoft/microsoft-adds-systemd-to-the-windows-subsystem-for-linux/\n'
#                 '\n'
#                 "This image shows its own MD5 checksum — and it's kind of a "
#                 'big deal - '
#                 'https://www.bleepingcomputer.com/news/security/this-image-shows-its-own-md5-checksum-and-its-kind-of-a-big-deal/\n'
#                 '\n'
#                 '#wsl #systemd #microsoft #canonical #linux #png #md5 '
#                 '#hashquine\n'
#                 '\n'
#                 '\n'
#                 '--- \n'
#                 '\n'
#                 'Send in a voice message: '
#                 'https://podcasters.spotify.com/pod/show/edodusi/message',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/systemd-su-wsl-e-png-che-contengono-il-loro-stesso-md5/id1641061765?i=1000580771305&uo=4',
#            'direct': 'https://anchor.fm/s/b1bf48a0/podcast/play/58193690/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fstaging%2F2022-8-27%2F287900717-44100-2-14b62f86d8c1d.mp3'},
#  'title': 'systemd su WSL e PNG che contengono il loro stesso MD5'}
# {'ai_keywords': [{'rank': 1, 'value': 'Arch Linux'},
#                  {'rank': 2, 'value': 'Zorin OS'},
#                  {'rank': 3, 'value': 'MX Linux'},
#                  {'rank': 4, 'value': 'Honix'}],
#  'ai_summary': 'This week in Linux saw the release of several new versions of '
#                'popular Linux distributions, including Arch Linux, Zorin OS, '
#                'and MX Linux. These releases often come with updated software '
#                'packages, bug fixes, and other improvements. Additionally, '
#                'Honix, a privacy-focused Linux distribution, released a new '
#                'version based on Debian 12 and Bookworm. Honnex provides a '
#                'layer of protection for internet traffic through its '
#                'innovative architecture, making it difficult for malware and '
#                'IP leaks to occur.',
#  'description': 'On this episode of This Week in Linux, Asahi Linux announced '
#                 'a major change with a new flagship distro for using Linux on '
#                 'Apple Silicon. GNOME and KDE released some exciting news for '
#                 'their respective desktop environments. systemd has a cool new '
#                 'feature called soft reboot and we have a whole lot of distro '
#                 'news for you from Arch Linux, Zorin OS, MX Linux and more. If '
#                 'this is your first TWIL, This Week in Linux is the news show '
#                 'that keeps you up to date with what’s going on in the Linux '
#                 'and Open Source world. So let’s jump right into Your Source '
#                 'for Linux GNews.\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'FORUM THREAD ►► '
#                 'https://forum.tuxdigital.com/t/228-fedora-asahi-gnome-tiling-kde-plasma-6-systemd-zorin-inkscape-amp-more-linux-news/5914\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'SPONSORED BY:LINBIT ►► https://linbit.com/\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'TWITTER ►► https://twitter.com/michaeltunnellMASTODON ►► '
#                 'https://mastodon.social/@MichaelTunnell\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'MERCH ►► https://tuxdigital.com/storeBECOME A PATRON ►► '
#                 'https://tuxdigital.com/membership\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'Chapters:\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '00:00 TWIL 228 Intro00:44 Fedora Asahi Remix: New Flagship '
#                 'Distro for Apple Silicon – [ link ]02:21 GNOME Considers New '
#                 'Tiling Window Management – [ link ]05:59 LINBIT ( '
#                 'https://linbit.com )07:23 KDE Plasma 6 News – [ link ]13:04 '
#                 'systemd 254 Released – [ link ]14:17 Inkscape 1.3 Released – '
#                 '[ link ]15:22 Arch Linux New Release – [ link ]17:02 Zorin OS '
#                 '16.3 Released – [ link ]19:19 MX Linux 23 Released – [ link '
#                 ']21:07 Whonix 17 Released – [ link ]22:37 Outro\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'Other Videos:17 KDE Plasma Features That You Didn’t Know '
#                 'About: https://www.youtube.com/watch?v=zhPIwFC4qFsGamify Your '
#                 'Life with Habitica, A To-Do List RPG To Get Things Done: '
#                 'https://www.youtube.com/watch?v=230NecNTaSA5 Reasons Why I '
#                 'Use KDE Plasma: https://youtu.be/b0KA6IsO1M87 Reasons Why '
#                 'Firefox Is My Favorite Web Browser: '
#                 'https://youtu.be/bGTBH9yr8uwHow To Use Firefox’s Best '
#                 'Feature, Multi-Account Containers: '
#                 'https://youtu.be/FfN5L5zAJUo',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/228-fedora-asahi-gnome-tiling-kde-plasma-6-systemd/id1689396651?i=1000623600545&uo=4',
#            'direct': 'https://media.blubrry.com/tuxdigital_thisweekinlinux_mp3/aphid.fireside.fm/d/1437767933/2389be04-5c79-485e-b1ca-3a5b2cebb006/ad5270a5-e830-41c6-bc57-219a04b528af.mp3'},
#  'title': '228: Fedora Asahi, GNOME Tiling, KDE Plasma 6, systemd, Zorin, '
#           'Inkscape & more Linux news!'}
# /Users/cfe/Dev/smarter-scraping/dataset/2024-02-13/posts/39344643/recommended
# {'ai_keywords': [{'rank': 1, 'value': 'Halloween'},
#                  {'rank': 2, 'value': 'costumes'},
#                  {'rank': 3, 'value': 'children'},
#                  {'rank': 4, 'value': "Betty's Spaghetti"},
#                  {'rank': 5, 'value': 'movie'}],
#  'ai_summary': 'Discussing Halloween costumes and divulging information about '
#                "children's Halloween plans. Chris shares his struggles with "
#                "remembering his youngest son's name, while the hosts discuss "
#                'their own Halloween costume ideas. They also talk about a '
#                "movie called 'Betty's Spaghetti' and its impact on them as "
#                'children.',
#  'description': 'This week kicks off with a recap of GigCity Elixir. Chris and '
#                 'Amos encourage people to attend smaller conferences because, '
#                 "seriously, they're way more fun.\n"
#                 '\n'
#                 '\n'
#                 'Chris is building RPC to see if it helps solve some of the '
#                 "coordination issues that he's experiencing at work. The "
#                 'conversation moves to the concept of autonomy and leverage in '
#                 'software systems and how to help teams align on larger '
#                 'goals.\n'
#                 '\n'
#                 '\n'
#                 "Dave's latest talk from GigCity is referenced and Chris "
#                 'expounds on his love for Datalog.\n'
#                 '\n'
#                 '\n'
#                 'Finally the hosts indulge in multiple divergences in which '
#                 'they divulge information about their personal lives.\n'
#                 'Support Elixir Outlaws',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/episode-58-all-about-some-datalog/id1372617417?i=1000456176903&uo=4',
#            'direct': 'https://aphid.fireside.fm/d/1437767933/4b3f9fe7-b118-4f29-b6ee-7baf2571b03c/b7a58ef1-dca0-4bba-ae85-f03380b89403.mp3'},
#  'title': 'Episode 58: All about some Datalog'}
# {'ai_keywords': [{'rank': 1, 'value': 'data science'},
#                  {'rank': 2, 'value': 'industry'},
#                  {'rank': 3, 'value': 'business'},
#                  {'rank': 4, 'value': 'informed decision'},
#                  {'rank': 5, 'value': 'skill'}],
#  'ai_summary': 'In this podcast, we will be discussing the importance of data '
#                "science in today's world. We will be talking about how data "
#                'science is revolutionizing various industries and how it can '
#                'help businesses make informed decisions. We will also be '
#                'discussing the skills required to become a data scientist and '
#                'the job prospects available in this field. ',
#  'description': 'Sebagian dari kamu mungkin terinspirasi ingin bekarir sebagai '
#                 'data scientist. Tapi apakah kamu benar sudah tau lingkup '
#                 'kerja seorang DS atau data scientist? Jurusan kuliah apa yang '
#                 'sebaiknya ditempuh? Kalau sudah terlanjur ambil jurusan '
#                 'modern art gak bisa jadi data scientist dong? Eits! '
#                 'pertanyaan-pertanyan tersebut (mungkin) akan dijawab di '
#                 'episode DataLog kali ini! Mari merapat dan simak!',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/jika-aku-menjadi-data-scientist/id1569195021?i=1000536467166&uo=4',
#            'direct': 'https://anchor.fm/s/5c1a3db0/podcast/play/40595102/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fstaging%2F2021-8-21%2F56e58419-49c9-f7c4-3f70-d94bae152165.mp3'},
#  'title': 'Jika Aku Menjadi Data Scientist'}
# {'ai_keywords': [{'rank': 1, 'value': 'a'},
#                  {'rank': 2, 'value': 'b'},
#                  {'rank': 3, 'value': 'c'},
#                  {'rank': 4, 'value': 'd'},
#                  {'rank': 5, 'value': 'e'}],
#  'ai_summary': 'This ice has different thicknesses, ranging from 1.5mm to '
#                '3.5mm.',
#  'description': 'Magematix & Datalog // Live @ STÜX\n'
#                 '2022_july\n'
#                 '\n'
#                 '✪ // www.tilos.hu \n'
#                 '✪ // FM90.3\n'
#                 '✪ // www.facebook.com/beatsafaridnb/\n'
#                 '✪ // iTunes Podcast // '
#                 'https://podcasts.apple.com/hu/podcast/tilos-radio-show/id1535637045',
#  'links': {'applePodcasts': 'https://podcasts.apple.com/us/podcast/magematix-datalog-live-st%C3%BCx/id1535637045?i=1000575413261&uo=4',
#            'direct': 'https://feeds.soundcloud.com/stream/1305959695-beatsafaridnb-magematix-datalog-live-stux.mp3'},
#  'title': 'Magematix & Datalog // Live @ STÜX'}
